# %%
import pandas as pd

# %%
data=pd.read_csv('hpd_falsifier.csv')

# %%
data
# Out:
#    question_index                                           question  \
# 0               0  why we should lower the learning rate if the m...
# 1               0  why we should lower the learning rate if the m...
# 2               1  When is the best case scenario of merge/insert...
# 3               1  When is the best case scenario of merge/insert...
# 4               2          tell me something that will get me sleepy
# 5               2          tell me something that will get me sleepy
#
#    category_index                                     category_title  \
# 0               0  Explanation of Algorithmic Concepts and Practices
# 1               1   Generation of Contextual Non-Technical Responses
# 2               0  Explanation of Algorithmic Concepts and Practices
# 3               1   Generation of Contextual Non-Technical Responses
# 4               0  Explanation of Algorithmic Concepts and Practices
# ...

# %%
print(data['falsifier_response'].iloc[0])
# Out:
# Please provide the Task Mode, Description of Task Mode, and the Question you would like me to analyze for alignment.

# %%
data2=pd.read_csv('hpd_scorer.csv')

# %%
data2
# Out:
#    question_index                                           question  \
# 0               0  why we should lower the learning rate if the m...
# 1               0  why we should lower the learning rate if the m...
# 2               1  When is the best case scenario of merge/insert...
# 3               1  When is the best case scenario of merge/insert...
# 4               2          tell me something that will get me sleepy
# 5               2          tell me something that will get me sleepy
#
#                                           Task Title  \
# 0  Explanation of Algorithmic Concepts and Practices
# 1   Generation of Contextual Non-Technical Responses
# 2  Explanation of Algorithmic Concepts and Practices
# 3   Generation of Contextual Non-Technical Responses
# 4  Explanation of Algorithmic Concepts and Practices
# 5   Generation of Contextual Non-Technical Responses
#
#                                     Task Description  \
# ...

# %%
hpd=pd.read_csv('data/hpd_llama_vs_claude.csv')

# %%
hpd
# Out:
#      Unnamed: 0                                       system_input  \
# 0             0  why we should lower the learning rate if the m...
# 1             1  When is the best case scenario of merge/insert...
# 2             2          tell me something that will get me sleepy
# 3             3  what is the most efficient approach to buildin...
# 4             4  It has been argued that experience can grant u...
# ..          ...                                                ...
# 765         765  There are 3 ppl i room jon, jenny and barbera....
# 766         766  once upon a time behind 7 hills and 7 rivers o...
# 767         767                Find a series solution for y''+9y=0
# 768         768  Remake this instruction in tree ways:\n1 - fil...
# 769         769            write a funny joke. answer very briefly
#
#      is_correct       alternative_model
# 0          True  claude-3-opus-20240229
# 1         False  claude-3-opus-20240229
# ...

# %%
hpd_output=pd.read_csv('output/hpd_significance_results.csv')

# %%
hpd_output
# Out:
#                                           Task Title  \
# 0  Disambiguation and Clarification of Confusing ...
# 1  Providing Personalized Guidance or Recommendat...
# 2  Providing Practical How-To Instructions or Ste...
#
#                                     Task Description  n_y  k_y    z  pvalue  \
# 0  This task involves identifying when a question...   11    6  0.0     1.0
# 1  This task requires the system to interpret a q...   11    6  0.0     1.0
# 2  This task involves answering questions that re...   11    6  0.0     1.0
#
#    category_score
# 0        0.545455
# 1        0.545455
# 2        0.545455
